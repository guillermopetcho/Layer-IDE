# %% [markdown]
# # Layer Notebook Dash Demo 🚀
#
# This notebook demonstrates how to launch an interactive IDE inside Kaggle / Jupyter notebooks using `Layer.Dash`.

# %%
# 1. Import Layer
import Layer

# 2. Launch interactive IDE for current directory
Layer.Dash(".")
